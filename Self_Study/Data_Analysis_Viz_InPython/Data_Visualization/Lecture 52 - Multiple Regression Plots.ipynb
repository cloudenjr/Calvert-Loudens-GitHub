# %%
# Let's begin by importing what we'll need (You'll probably be copying and pasting this a lot)

# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series,DataFrame

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules and libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook(Jupyter Notebook)
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>sex</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.99</td>
#       <td>1.01</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.34</td>
#       <td>1.66</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
# Using .lmplot() function to plot regression models
sns.lmplot('total_bill','tip',tips)

# %%
# Using dicitionaries to edit individual parts of the plot
# if you dont want a linear fit, you can specify what order fit you want.
sns.lmplot('total_bill','tip',tips,order=4,
           scatter_kws={'marker':'o','color':'indianred'},
           line_kws={'linewidth':1,'color':'blue'})

# %%
# Pure scatter plot with no regression line at all
sns.lmplot('total_bill','tip',tips,fit_reg=False)

# %%
# '.lmplot()' function also works on discrete variables, like the % of the tip
tips.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>sex</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.99</td>
#       <td>1.01</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.34</td>
#       <td>1.66</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
# Making a new column, 'Tip_pct'
tips['tip_pct'] = 100*(tips['tip']/tips['total_bill'])

# %%
tips.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>sex</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#       <th>tip_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.99</td>
#       <td>1.01</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#       <td>5.944673</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.34</td>
#       <td>1.66</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
# ...

# %%
sns.lmplot('size','tip_pct',tips)

# %%
url = 'http://en.wikipedia.org/wiki/Jitter'

# %%
# Use Jitter to make lmplot easier to read; spreads datapoints out width-wise so overlaps more distinguishable
sns.lmplot('size','tip_pct',tips,x_jitter=.1)

# %%
# Estimating the tendency of each bin
sns.lmplot('size','tip_pct',tips,x_estimator=np.mean)

# %%
# Use the 'hue' facet to automatically define subsets along a column
# This syntax creates a scatter & linear regr plot for both male and female
sns.lmplot('total_bill','tip_pct',tips,hue='sex',markers=['x','o'])

# %%
# Problem:  Does the day make a difference in how much the tip is?
sns.lmplot('total_bill','tip_pct',tips,hue='day')

# %%
url = 'http://en.wikipedia.org/wiki/Local_regression'

sns.lmplot('total_bill','tip_pct',tips,lowess=True,line_kws={'color':'black'})

# %%
# '.regplot()' is more robust plotting function than '.lmplot()'
sns.regplot('total_bill','tip_pct',tips)

# %%
# Creating a figure with 2 subplots
fig, (axis1,axis2) = plt.subplots(1,2,sharey=True)

sns.regplot('total_bill','tip_pct',tips,ax=axis1)
sns.violinplot(tips['tip_pct'],tips['size'],color='Reds_r',ax=axis2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     131     try:
# --> 132         rgba = _colors_full_map.cache[c, alpha]
#     133     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('Reds', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9e94cbcd97ce> in <module>()
#       3
#       4 sns.regplot('total_bill','tip_pct',tips,ax=axis1)
# ----> 5 sns.violinplot(tips['tip_pct'],tips['size'],color='Reds',ax=axis2)
#
# ...
